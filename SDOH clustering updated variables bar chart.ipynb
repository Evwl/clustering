# %%
# Importing necessary libraries
import pandas as pd
import pyreadstat

# Path to your SPSS file
spss_file_path = '/Users/evonwong/Downloads/26 June UKBB_SDOH_kmeancluster_data_k4_updatedvariables.sav'
# Reading the SPSS file
df, meta = pyreadstat.read_sav(spss_file_path)

# df is a pandas DataFrame containing your data
# meta is a metadata object with information about the file

# Displaying the first few rows of the dataframe
print(df.head())

# Optionally, inspect the metadata
print(meta.variable_value_labels)  # Shows value labels for categorical variables
# Out:
#          EID  Census_High_Skill_Employment_rev_standardized  \
# 0  1000016.0                                      -0.159862
# 1  1000029.0                                      -0.533702
# 2  1000033.0                                       1.504422
# 3  1000045.0                                       1.400604
# 4  1000051.0                                       0.125917
#
#    Census_Managers_Directors_Senior_Officials_rev_standardized  \
# 0                                           0.345245
# 1                                          -0.719905
# 2                                           0.493482
# 3                                           0.712811
# 4                                           0.345245
#
#    Census_Professional_rev_standardized  \
# 0                             -0.343395
# 1                             -0.452810
# 2                              2.071832
# 3                              1.447274
# 4                             -0.185030
#
# ...

# %%
# # Selecting columns needed for analysis
# columns_needed = [
# "ONS_Net_Weekly_Income_rev_standardized", 
#         "IMD_2010_Income_IDACI_standardized", 
#         "IMD_2010_Income_IDAOPI_standardized",
#         "Census_Economically_Active_rev_standardized", 
#         "Census_Economically_Inactive_standardized", 
#         "Census_No_Adults_Employment_standardized",
#         "Census_High_Skill_Employment_rev_standardized", 
#         "Census_Managers_Directors_Senior_Officials_rev_standardized", 
#         "Census_Professional_rev_standardized", 
#         "Census_Associate_Professional_rev_standardized", 
#         "IMD_2010_Employmen_standardized",
# #######SDOH_EDUCATION_DOMAIN##############
# "Census_No_Qualification_standardized", 
#         "IMD_2010_Children_Young_People_standardized", 
#         "IMD_Skills_standardized", 
#         "IMD_Not_Staying_on_in_Edu_standardized", 
#         "IMD_Not_Enter_Higher_Edu_standardized",
# ########### SDOH_HEALTH_DOMAIN###############
# "PHP_Winter_Mortality_standardized", 
#         "Census_Disability_standardized", 
#         "IMD_Potential_Life_Lost_standardized", 
#         "IMD_Comparative_Illness_Disability_standardized", 
#         "IMD_Acute_Morbidity_standardized", 
#         "IMD_Mood_Anxiety_standardized",


# ########### SDOH_NEIGHBORHOOD_BUILD_ENVIRONMENT#######
# "Census_Pop_Density_standardized", 
#         "Census_Avg_Household_Size_standardized", 
#         "Census_No_Central_Heating_standardized", 
#         "IMD_Wider_Barriers_standardized",
#         "IMD_Affordability_indicator_standardized", 
#         "Census_Comm_Estab_standardized", 
#         "IMD_Geographical_Barriers_standardized", 
#         "IMD_Distance_GP_indicator_standardized", 
#         "IMD_Distance_Food_Shop_standardized", 
#         "IMD_Distance_Primary_School_standardized", 
#         "IMD_Distance_Post_Office_standardized", 
#         "Census_No_Car_Vans_standardized", 
#         "IMD_Traffic_Accident_standardized",
#         "IMD_Air_quality_standardized", 
#         "IMD_NO2_standardized", 
#         "NO2_2010_standardized",
#         "IMD_PM_standardized", 
#         "PM2.5_2010_standardized",
#         "PM10_2010_standardized",
#         "IMD_SO2_standardized", 
#         "IMD_Benzene_standardized", 
#         "Greenspace_1000m_rev_standardized",
#         # "Greenspace_300m_rev_standardized",
#         "Natural_Enviro_1000m_rev_standardized",
#         # "Natural_Enviro_300m_rev_standardized",

# ###############SDOH_SOCIAL_AND_COMMUNITY_CONTEXT###################

# "ONS_2010_population_18_p_standardized",
# "ONS_2010_population_65_p_standardized",
# # "Census_Household_Deprivation_standardized",
# "Census_Ethnic_Groups_standardized",
# "Census_Limited_English_Proficiency_standardized",
# "Census_Single_standardized",
# "PHP_Smoking_Prevalence_standardized",
# "PHP_Violent_Crime_standardized",
# "IMD_2010_Crime_Disorder_standardized",
# "PHP_Suicide_standardized",
# "PHP_Self_Harm_standardized"]

# %%
rename_dict = {
    "ONS_Net_Weekly_Income_rev_standardized": "Net weekly household income before housing costs",
    "IMD_2010_Income_IDACI_standardized": "IMD Income deprivation affecting children index",
    "IMD_2010_Income_IDAOPI_standardized": "IMD Income deprivation affecting older people index",
    "Census_Economically_Active_rev_standardized": "Economic activity (active) – reversed",
    "Census_Economically_Inactive_standardized": "Economic activity (inactive)",
    "Census_No_Adults_Employment_standardized": "Household composition (no adults in employment in household)",
    "Census_High_Skill_Employment_rev_standardized": "High-skill employment",
    "Census_Managers_Directors_Senior_Officials_rev_standardized": "High-skill employment (managers, directors, and senior officials)",
    "Census_Professional_rev_standardized": "High-skill employment (professional occupations)",
    "Census_Associate_Professional_rev_standardized": "High-skill employment (associate professional and technical occupations)",
    "IMD_2010_Employmen_standardized": "IMD Employment",
    "Census_No_Qualification_standardized": "No qualification",
    "IMD_2010_Children_Young_People_standardized": "IMD Children and young people",
    "IMD_Skills_standardized": "IMD Skills",
    "IMD_Not_Staying_on_in_Edu_standardized": "IMD Not staying on in education",
    "IMD_Not_Enter_Higher_Edu_standardized": "IMD Not entering higher education",
    "PHP_Winter_Mortality_standardized": "Winter mortality index (health protection)",
    "Census_Disability_standardized": "Disability (all categories): long-term health problem or disability",
    "IMD_Potential_Life_Lost_standardized": "IMD Years of potential life lost",
    "IMD_Comparative_Illness_Disability_standardized": "IMD Comparative illness and disability ratio",
    "IMD_Acute_Morbidity_standardized": "IMD Measures of acute morbidity",
    "IMD_Mood_Anxiety_standardized": "IMD Proportion of adults under 60 suffering from mood or anxiety disorders",
    "Census_Pop_Density_standardized": "Population density",
    "Census_Avg_Household_Size_standardized": "Average household size",
    "Census_No_Central_Heating_standardized": "Houses without central heating",
    "IMD_Wider_Barriers_standardized": "IMD Wider barriers",
    "IMD_Affordability_indicator_standardized": "IMD Affordability",
    "Census_Comm_Estab_standardized": "Communal establishment",
    "IMD_Geographical_Barriers_standardized": "IMD Geographical barriers",
    "IMD_Distance_GP_indicator_standardized": "IMD Road distance to a GP surgery",
    "IMD_Distance_Food_Shop_standardized": "IMD Road distance to a food shop",
    "IMD_Distance_Primary_School_standardized": "IMD Road distance to a primary school",
    "IMD_Distance_Post_Office_standardized": "IMD Road distance to a post office",
    "Census_No_Car_Vans_standardized": "Car or van availability",
    "IMD_Traffic_Accident_standardized": "Road traffic accidents",
    "IMD_Air_quality_standardized": "IMD Air quality",
    "IMD_NO2_standardized": "IMD NO2",
    "NO2_2010_standardized": "NO2",
    "IMD_PM_standardized": "IMD Particulates",
    "PM2.5_2010_standardized": "PM 2.5",
    "PM10_2010_standardized": "PM 10",
    "IMD_SO2_standardized": "IMD SO2",
    "IMD_Benzene_standardized": "IMD Benzene",
    "Greenspace_1000m_rev_standardized": "Greenspace 1000 m buffer (reversed)",
    "Natural_Enviro_1000m_rev_standardized": "Natural environment 1000 m buffer (reversed)",
    "ONS_2010_population_18_p_standardized": "Population <18",
    "ONS_2010_population_65_p_standardized": "Population >65",
    "Census_Ethnic_Groups_standardized": "Population from ethnic minorities",
    "Census_Limited_English_Proficiency_standardized": "Limited English proficiency",
    "Census_Single_standardized": "Single-headed households",
    "PHP_Smoking_Prevalence_standardized": "Smoking prevalence in adults (aged 18 or over)",
    "PHP_Violent_Crime_standardized": "Violent crime - hospital admissions for violence (including sexual violence)",
    "IMD_2010_Crime_Disorder_standardized": "IMD Crime and disorder score",
    "PHP_Suicide_standardized": "Suicide rate",
    "PHP_Self_Harm_standardized": "Emergency hospital admissions for intentional self-harm"
}

# %%
df.rename(columns=rename_dict, inplace=True)

# %%
columns_needed = [
"Net weekly household income before housing costs",
"IMD Income deprivation affecting children index",
"IMD Income deprivation affecting older people index",
"Economic activity (active) – reversed",
"Economic activity (inactive)",
"Household composition (no adults in employment in household)",
"High-skill employment",
"High-skill employment (managers, directors, and senior officials)",
"High-skill employment (professional occupations)",
"High-skill employment (associate professional and technical occupations)",
"IMD Employment",
"No qualification",
"IMD Children and young people",
"IMD Skills",
"IMD Not staying on in education",
"IMD Not entering higher education",
"Winter mortality index (health protection)",
"Disability (all categories): long-term health problem or disability",
"IMD Years of potential life lost",
"IMD Comparative illness and disability ratio",
"IMD Measures of acute morbidity",
"IMD Proportion of adults under 60 suffering from mood or anxiety disorders",
"Population density",
"Average household size",
"Houses without central heating",
"IMD Wider barriers",
"IMD Affordability",
"Communal establishment",
"IMD Geographical barriers",
"IMD Road distance to a GP surgery",
"IMD Road distance to a food shop",
"IMD Road distance to a primary school",
"IMD Road distance to a post office",
"Car or van availability",
"Road traffic accidents",
"IMD Air quality",
"IMD NO2",
"NO2",
"IMD Particulates",
"PM 2.5",
"PM 10",
"IMD SO2",
"IMD Benzene",
"Greenspace 1000 m buffer (reversed)", 
"Natural environment 1000 m buffer (reversed)",
"Population <18",
"Population >65",
"Population from ethnic minorities",
"Limited English proficiency",
"Single-headed households",
"Smoking prevalence in adults (aged 18 or over)",
"Violent crime - hospital admissions for violence (including sexual violence)",
"IMD Crime and disorder score",
"Suicide rate",
"Emergency hospital admissions for intentional self-harm"]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
domain_colors = {
    "Economics Stability": "#6baed6",  # Soft Blue
    "Education": "#74c476",  # Soft Green
    "Health": "#fd8d3c",    # Soft Orange
    "Neighborhood and Built Environment": "#bc5090",  # Soft Pink
    "Social and Community Context": "#9c9ede"  # Lavender
}

# Create a list to hold the color for each column based on its domain
colors = []
for col in columns_needed:
    if col in [
        "Net weekly household income before housing costs",
        "IMD Income deprivation affecting children index",
        "IMD Income deprivation affecting older people index",
        "Economic activity (active) – reversed",
        "Economic activity (inactive)",
        "Household composition (no adults in employment in household)",
        "High-skill employment",
        "High-skill employment (managers, directors, and senior officials)",
        "High-skill employment (professional occupations)",
        "High-skill employment (associate professional and technical occupations)",
        "IMD Employment"
    ]:
        colors.append(domain_colors["Economics Stability"])
    elif col in [
        "No qualification",
        "IMD Children and young people",
        "IMD Skills",
        "IMD Not staying on in education",
        "IMD Not entering higher education"
    ]:
        colors.append(domain_colors["Education"])
    elif col in [
        "Winter mortality index (health protection)",
        "Disability (all categories): long-term health problem or disability",
        "IMD Years of potential life lost",
        "IMD Comparative illness and disability ratio",
        "IMD Measures of acute morbidity",
        "IMD Proportion of adults under 60 suffering from mood or anxiety disorders"
    ]:
        colors.append(domain_colors["Health"])
    elif col in [
        "Population density",
        "Average household size",
        "Houses without central heating",
        "IMD Wider barriers",
        "IMD Affordability",
        "Communal establishment",
        "IMD Geographical barriers",
        "IMD Road distance to a GP surgery",
        "IMD Road distance to a food shop",
        "IMD Road distance to a primary school",
        "IMD Road distance to a post office",
        "Car or van availability",
        "Road traffic accidents",
        "IMD Air quality",
        "IMD NO2",
        "NO2",
        "IMD Particulates",
        "PM 2.5",
        "PM 10",
        "IMD SO2",
        "IMD Benzene",
        "Greenspace 1000 m buffer (reversed)", 
        "Natural environment 1000 m buffer (reversed)"
    ]:
        colors.append(domain_colors["Neighborhood and Built Environment"])
    else:
        colors.append(domain_colors["Social and Community Context"])



# Creating a list of line objects for the legend
legend_lines = [
    Line2D([0], [0], color=color, lw=4) for domain, color in domain_colors.items()
]
# Assume df is your DataFrame containing these columns and a 'Cluster' column
df_selected = df[columns_needed + ['Cluster_k4_v2_recode']]
# Calculate the 5 quintile  for each variable
Q3 = df_selected[columns_needed].quantile(0.80)

# Function to calculate proportions exceeding Q3
def calculate_exceeding_proportions(group):
    exceeding = (group[columns_needed] > Q3).sum() / len(group) * 100
    return exceeding

# Group by 'Cluster' and apply the function
proportions = df_selected.groupby('Cluster_k4_v2_recode').apply(calculate_exceeding_proportions)

# Reverse the order of the DataFrame for plotting
proportions_reversed = proportions.iloc[::-1]

# Plotting with reversed order and line-based legend at the bottom
fig, axes = plt.subplots(nrows=len(proportions_reversed.index), figsize=(18, 5 * len(proportions_reversed.index)), sharex=True)

for i, (idx, group) in enumerate(proportions_reversed.iterrows()):
    ax = axes[i]
    group.plot(kind='bar', ax=ax, color=colors, alpha=0.75)
    ax.set_yticks(range(0, 101, 20))  # Adjusting to 101 because range is exclusive of the stop
    ax.set_ylim([0, 100])
    ax.set_xticklabels(group.index, rotation=90, ha="center", fontsize=12)

    # Adjust the text to say "Pattern {idx+1}" based on the reversed order
    pattern_number = len(proportions_reversed.index) - i  # Calculate correct pattern number
    ax.text(1.01, 0.5, f'Pattern {pattern_number}', transform=ax.transAxes, fontsize=16, fontweight='bold', color='navy',
            verticalalignment='center', horizontalalignment='left', rotation=90, bbox=dict(facecolor='white', alpha=0.5, edgecolor='navy', pad=2.0))

    ax.grid(True, which='major', linestyle='--', linewidth='0.5', color='grey',alpha=0.5)

# Remove individual y-axis labels from the subplots
for ax in axes:
    ax.set_ylabel('')

# Add a central y-axis label
fig.text(0.04, 0.5, 'Percentage of Participants (%) with Disadvantaged SDOH', va='center', rotation='vertical', fontsize=14)

# Adjust layout to prevent overlap and ensure clarity
fig.tight_layout(rect=[0.05, 0.03, 1, 0.9])  # Adjust the top margin to make space for the legend
fig.subplots_adjust(hspace=0.3, right=0.9, top=0.9)  # Adjust vertical space and top margin

# Adding the line-based legend at the bottom
fig.legend(handles=legend_lines, labels=[domain for domain in domain_colors.keys()], loc='upper center', bbox_to_anchor=(0.5, 0.02), ncol=len(domain_colors), frameon=False)

# Show and save the plot
plt.show()
# Save the figure, ensuring it's centered in the output file
fig.savefig('/Users/evonwong/Downloads/17 OCT SDOH_pattern_proportion_75_percent_k4recode_updated variables recoded.pdf', dpi=1200, format='pdf', bbox_inches='tight', pad_inches=0.5)
# Out:
# /var/folders/2l/nk08r53s3p15vgtdsrlv5nz40000gn/T/ipykernel_60773/2751482193.py:93: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   proportions = df_selected.groupby('Cluster_k4_v2_recode').apply(calculate_exceeding_proportions)

# %%
# Extract the vale
import pandas as pd

# === Step 1: Compute 80th percentile per variable ===
Q3 = df_selected[columns_needed].quantile(0.80)

# === Step 2: Define function to calculate proportions per cluster ===
def calculate_exceeding_proportions(group):
    # Percent of participants exceeding 80th percentile (Q3) for each variable
    exceeding = (group[columns_needed] > Q3).sum() / len(group) * 100
    return exceeding

# === Step 3: Apply function to each Pattern (Cluster) ===
proportions_table = (
    df_selected.groupby('Cluster_k4_v2_recode')
    .apply(calculate_exceeding_proportions)
)

# === Step 4: Transpose so that variables are rows and patterns are columns ===
proportions_table_T = proportions_table.T

# === Step 5: Clean up formatting ===
proportions_table_T = proportions_table_T.round(2)
proportions_table_T.index.name = "Variable"
proportions_table_T.columns.name = "Pattern"

# === Step 6: Display the neatly formatted table ===
print("\n=== Proportion (%) of participants exceeding 80th percentile per variable per Pattern ===\n")
print(proportions_table_T)

# === Step 7: Optional - save to CSV ===
proportions_table_T.to_csv("/Users/evonwong/Downloads/2SDOH_Exceed_Q80_byVariable.csv")
# Out:
# === Proportion (%) of participants exceeding 80th percentile per variable per Pattern ===
#
# Pattern                                               0.0    1.0    2.0    3.0
# Variable
# ONS_Net_Weekly_Income_rev_standardized               0.38   5.46  16.89  79.12
# IMD_2010_Income_IDACI_standardized                   0.61  36.67   6.12  77.99
# IMD_2010_Income_IDAOPI_standardized                  1.36  15.11  15.15  71.89
# Census_Economically_Active_rev_standardized         17.81   4.08  17.66  46.78
# Census_Economically_Inactive_standardized           15.01  24.87  11.24  49.26
# Census_No_Adults_Employment_standardized            10.36   7.53  18.22  58.82
# Census_High_Skill_Employment_rev_standardized        0.54   6.59  15.73  88.55
# Census_Managers_Directors_Senior_Officials_rev_...   0.61  11.28  14.31  82.06
# Census_Professional_rev_standardized                 1.20   5.48  16.61  85.10
# Census_Associate_Professional_rev_standardized       3.13   7.60  13.24  83.43
# ...

# %%
import pandas as pd

# Assuming df_selected is your original DataFrame already loaded with data

# Dictionary to map old column names to new, more descriptive names
rename_dict = {
    "ONS_Net_Weekly_Income_rev_standardized": "Net weekly household income before housing costs",
    "IMD_2010_Income_IDACI_standardized": "IMD Income deprivation affecting children index",
    "IMD_2010_Income_IDAOPI_standardized": "IMD Income deprivation affecting older people index",
    "Census_Economically_Active_rev_standardized": "Economic activity (active) – reversed",
    "Census_Economically_Inactive_standardized": "Economic activity (inactive)",
    "Census_No_Adults_Employment_standardized": "Household composition (no adults in employment in household)",
    "Census_High_Skill_Employment_rev_standardized": "High-skill employment",
    "Census_Managers_Directors_Senior_Officials_rev_standardized": "High-skill employment (managers, directors, and senior officials)",
    "Census_Professional_rev_standardized": "High-skill employment (professional occupations)",
    "Census_Associate_Professional_rev_standardized": "High-skill employment (associate professional and technical occupations)",
    "IMD_2010_Employmen_standardized": "IMD Employment",
    "Census_No_Qualification_standardized": "No qualification",
    "IMD_2010_Children_Young_People_standardized": "IMD Children and young people",
    "IMD_Skills_standardized": "IMD Skills",
    "IMD_Not_Staying_on_in_Edu_standardized": "IMD Not staying on in education",
    "IMD_Not_Enter_Higher_Edu_standardized": "IMD Not entering higher education",
    "PHP_Winter_Mortality_standardized": "Winter mortality index (health protection)",
    "Census_Disability_standardized": "Disability (all categories): long-term health problem or disability",
    "IMD_Potential_Life_Lost_standardized": "IMD Years of potential life lost",
    "IMD_Comparative_Illness_Disability_standardized": "IMD Comparative illness and disability ratio",
    "IMD_Acute_Morbidity_standardized": "IMD Measures of acute morbidity",
    "IMD_Mood_Anxiety_standardized": "IMD Proportion of adults under 60 suffering from mood or anxiety disorders",
    "Census_Pop_Density_standardized": "Population density",
    "Census_Avg_Household_Size_standardized": "Average household size",
    "Census_No_Central_Heating_standardized": "Houses without central heating",
    "IMD_Wider_Barriers_standardized": "IMD Wider barriers",
    "IMD_Affordability_indicator_standardized": "IMD Affordability",
    "Census_Comm_Estab_standardized": "Communal establishment",
    "IMD_Geographical_Barriers_standardized": "IMD Geographical barriers",
    "IMD_Distance_GP_indicator_standardized": "IMD Road distance to a GP surgery",
    "IMD_Distance_Food_Shop_standardized": "IMD Road distance to a food shop",
    "IMD_Distance_Primary_School_standardized": "IMD Road distance to a primary school",
    "IMD_Distance_Post_Office_standardized": "IMD Road distance to a post office",
    "Census_No_Car_Vans_standardized": "Car or van availability",
    "IMD_Traffic_Accident_standardized": "Road traffic accidents",
    "IMD_Air_quality_standardized": "IMD Air quality",
    "IMD_NO2_standardized": "IMD NO2",
    "NO2_2010_standardized": "NO2",
    "IMD_PM_standardized": "IMD Particulates",
    "PM2.5_2010_standardized": "PM 2.5",
    "PM10_2010_standardized": "PM 10",
    "IMD_SO2_standardized": "IMD SO2",
    "IMD_Benzene_standardized": "IMD Benzene",
    "Greenspace_1000m_rev_standardized": "Greenspace 1000 m buffer (reversed)",
    "Natural_Enviro_1000m_rev_standardized": "Natural environment 1000 m buffer (reversed)",
    "ONS_2010_population_18_p_standardized": "Population <18",
    "ONS_2010_population_65_p_standardized": "Population >65",
    "Census_Ethnic_Groups_standardized": "Population from ethnic minorities",
    "Census_Limited_English_Proficiency_standardized": "Limited English proficiency",
    "Census_Single_standardized": "Single-headed households",
    "PHP_Smoking_Prevalence_standardized": "Smoking prevalence in adults (aged 18 or over)",
    "PHP_Violent_Crime_standardized": "Violent crime - hospital admissions for violence (including sexual violence)",
    "IMD_2010_Crime_Disorder_standardized": "IMD Crime and disorder score",
    "PHP_Suicide_standardized": "Suicide rate",
    "PHP_Self_Harm_standardized": "Emergency hospital admissions for intentional self-harm"
}

# Rename the columns in the DataFrame
df_selected.rename(columns=rename_dict, inplace=True)

# Continue with your analysis script after renaming
# Compute the 80th percentile per variable
columns_needed = rename_dict.values()  # List of new variable names
Q3 = df_selected[columns_needed].quantile(0.80)

# Define function to calculate proportions per cluster
def calculate_exceeding_proportions(group):
    exceeding = (group[columns_needed] > Q3).sum() / len(group) * 100
    return exceeding

# Apply function to each pattern (cluster)
proportions_table = df_selected.groupby('Cluster_k4_v2_recode').apply(calculate_exceeding_proportions)

# Transpose the resulting table for better readability
proportions_table_T = proportions_table.T

# Clean up formatting
proportions_table_T = proportions_table_T.round(2)
proportions_table_T.index.name = "Variable"
proportions_table_T.columns.name = "Pattern"
# Classify the percentages into categories
def classify_percentage(val):
    if val < 20:
        return 'lowest'
    elif val < 40:
        return 'low'
    elif val < 60:
        return 'medium'
    elif val < 80:
        return 'high'
    else:
        return 'highest'

# Apply classification to each cell in the transposed table
categorized_table = proportions_table_T.applymap(classify_percentage)

# Create a new table that aggregates these categories
pattern_category_summary = {}
for pattern in categorized_table.columns:
    category_dict = {}
    for category in ['lowest', 'low', 'medium', 'high', 'highest']:
        category_dict[category] = categorized_table[pattern][categorized_table[pattern] == category].index.tolist()
    pattern_category_summary[pattern] = category_dict

# Convert dictionary to DataFrame for better display
pattern_category_df = pd.DataFrame.from_dict(pattern_category_summary, orient='index')

# Display the formatted DataFrame
print("\n=== Categorized Variables per Pattern ===\n")
print(pattern_category_df)

# Optionally, save to CSV
pattern_category_df.to_csv("/Users/evonwong/Downloads/Categorized_Variables_Per_Pattern.csv")
# Out:
# /var/folders/2l/nk08r53s3p15vgtdsrlv5nz40000gn/T/ipykernel_22289/42901525.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.rename(columns=rename_dict, inplace=True)
# === Categorized Variables per Pattern ===
#
#                                                 lowest  \
# 0.0  [Net weekly household income before housing co...
# 1.0  [Net weekly household income before housing co...
# 2.0  [Net weekly household income before housing co...
# 3.0  [Winter mortality index (health protection), A...
#
#                                                    low  \
# 0.0  [Winter mortality index (health protection), A...
# 1.0  [IMD Income deprivation affecting children ind...
# 2.0  [IMD Not staying on in education, Disability (...
# 3.0  [Disability (all categories): long-term health...
# ...
